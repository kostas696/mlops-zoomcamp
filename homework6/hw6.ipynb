# %% [markdown]
# ## Question 1

# %% [markdown]
# ```
# if __name__ == '__main__':
#     year = int(sys.argv[1])
#     month = int(sys.argv[2])
#     main(year, month)
#     print(f'processing year={year}, month={month}')
# ```

# %% [markdown]
# ```
# bash
#
# python batch.py 2023 3
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 2

# %% [markdown]
# ```__init__.py```

# %% [markdown]
# ## Question 3

# %% [markdown]
# We run the test for 1, 2, 3, 4 rows and we see that for 2 the test is passed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 4

# %% [markdown]
# Download the raw file for March 2023
# ```
# wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet
# ```

# %% [markdown]
# Environmental variables
#
# ```
# export INPUT_FILE_PATTERN="s3://nyc-duration/in/{year:04d}-{month:02d}.parquet"
# export OUTPUT_FILE_PATTERN="s3://nyc-duration/out/{year:04d}-{month:02d}.parquet"
# export S3_ENDPOINT_URL=http://localhost:4566
# export AWS_ACCESS_KEY_ID=test
# export AWS_SECRET_ACCESS_KEY=test
# ```

# %% [markdown]
# Upload existing local file to that exact path in Localstack’s S3 bucket
# ```
# aws --endpoint-url=http://localhost:4566 s3 cp yellow_tripdata_2023-03.parquet s3://nyc-duration/in/2023-03.parquet
# ```

# %% [markdown]
# Run the pipeline
# ```
# python batch.py 2023 3
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 5

# %% [markdown]
# Run integration_test
# ```
# python tests/integration_test.py
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Run the shell script
# ```
# ./run_integration_test.sh
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
