# %%
import numpy as np
import pandas as pd 

import os
for dirname, _, filenames in os.walk(r"C:\Users\Jasmina PC\Downloads\mlops2"):
    for filename in filenames:
        print(os.path.join(dirname, filename))


import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Jasmina PC\Downloads\mlops2\2-experiment-tracking-mlops.ipynb
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-01.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-02.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-03.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\mlflow.db
# C:\Users\Jasmina PC\Downloads\mlops2\preprocess_data.py
# C:\Users\Jasmina PC\Downloads\mlops2\train.py

# %%
# %pip install --q mlflow

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2024/05/27 16:03:53 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/05/27 16:03:54 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 451aebb31d03, add metric step
# INFO  [alembic.runtime.migration] Running upgrade 451aebb31d03 -> 90e64c465722, migrate user column to tags
# INFO  [alembic.runtime.migration] Running upgrade 90e64c465722 -> 181f10493468, allow nulls for metric values
# INFO  [alembic.runtime.migration] Running upgrade 181f10493468 -> df50e92ffc5e, Add Experiment Tags Table
# INFO  [alembic.runtime.migration] Running upgrade df50e92ffc5e -> 7ac759974ad8, Update run tags with larger limit
# INFO  [alembic.runtime.migration] Running upgrade 7ac759974ad8 -> 89d4b8295536, create latest metrics table
# ...

# %% [markdown]
# ## Q1. Install MLflow

# %%
print(mlflow.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ## Q2. Download and preprocess the data

# %%
# !python preprocess_data.py --raw_data_path nyc-trips-jan-feb-mar-2023-green --dest_path ./output
# Out:
# python: can't open file 'c:\\Users\\Jasmina PC\\Downloads\\preprocess_data.py': [Errno 2] No such file or directory

# %%
output_files = os.listdir('./output')
print(f"Number of files saved: {len(output_files)}")
# Out:
# Number of files saved: 4

# %% [markdown]
# ## Q3. Train a model with autolog

# %%
# !python /kaggle/input/trainmodel/train.py --data_path /kaggle/working/output
# Out:
# 2024/05/26 20:21:55 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/26 20:22:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/conda/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# RMSE: 5.431162180141208

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 13
#      11 experiment = mlflow.get_experiment_by_name(experiment_name)
#      12 client = mlflow.tracking.MlflowClient()
# ---> 13 runs = client.search_runs(experiment.experiment_id, order_by=["start_time desc"], max_results=1)
#      14 latest_run_id = runs[0].info.run_id
#      16 print_run_params(latest_run_id)
#
# AttributeError: 'NoneType' object has no attribute 'experiment_id'
