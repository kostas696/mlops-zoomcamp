# %%
import numpy as np
import pandas as pd 

import os
for dirname, _, filenames in os.walk(r"C:\Users\Jasmina PC\Downloads\mlops2"):
    for filename in filenames:
        print(os.path.join(dirname, filename))


import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Jasmina PC\Downloads\mlops2\2-experiment-tracking-mlops.ipynb
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-01.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-02.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\green_tripdata_2023-03.parquet
# C:\Users\Jasmina PC\Downloads\mlops2\hpo.py
# C:\Users\Jasmina PC\Downloads\mlops2\mlflow.db
# C:\Users\Jasmina PC\Downloads\mlops2\preprocess_data.py
# C:\Users\Jasmina PC\Downloads\mlops2\train.py
# C:\Users\Jasmina PC\Downloads\mlops2\mlruns\584978072540560010\meta.yaml
# C:\Users\Jasmina PC\Downloads\mlops2\mlruns\584978072540560010\425db1fbb57c4968b4a52cd9557c857f\meta.yaml
# C:\Users\Jasmina PC\Downloads\mlops2\mlruns\584978072540560010\425db1fbb57c4968b4a52cd9557c857f\artifacts\estimator.html
# C:\Users\Jasmina PC\Downloads\mlops2\mlruns\584978072540560010\425db1fbb57c4968b4a52cd9557c857f\artifacts\model\conda.yaml
# ...

# %%
import os

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='file:///c:/Users/Jasmina PC/Downloads/mlruns/1', creation_time=1716817561923, experiment_id='1', last_update_time=1716817561923, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %% [markdown]
# ## Q1. Install MLflow

# %%
print(mlflow.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ## Q2. Download and preprocess the data

# %%
# !python "C:/Users/Jasmina PC/Downloads/mlops2/preprocess_data.py" --raw_data_path "C:/Users/Jasmina PC/Downloads/mlops2" --dest_path "C:/Users/Jasmina PC/Downloads/mlops2/output"

# %%
output_files = os.listdir('./output')
print(f"Number of files saved: {len(output_files)}")
# Out:
# Number of files saved: 4

# %% [markdown]
# ## Q3. Train a model with autolog

# %%
# !python "C:/Users/Jasmina PC/Downloads/mlops2/train.py" --data_path "C:/Users/Jasmina PC/Downloads/mlops2/output"
# Out:
# RMSE: 5.431162180141208
# 2024/05/27 22:12:20 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/27 22:13:51 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: Unable to allocate 2.66 GiB for an array with shape (356796948,) and data type float64
# c:\Users\Jasmina PC\.conda\envs\mlflow\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %% [markdown]
# ## Q4. Launch the tracking server locally

# %% [markdown]
# mlflow server --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./artifacts --host 127.0.0.1 --port 5000

# %% [markdown]
# ## Q5. Tune model hyperparameters

# %%
# !python "C:/Users/Jasmina PC/Downloads/mlops2/hpo.py" --data_path "C:/Users/Jasmina PC/Downloads/mlops2/output"
# Out:
# ...
# 100%|██████████| 15/15 [04:20<00:00, 17.35s/trial, best loss: 5.335419588556921]
# Best result: {'max_depth': 19.0, 'min_samples_leaf': 2.0, 'min_samples_split': 2.0, 'n_estimators': 11.0}
# 2024/05/27 22:32:17 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
# c:\Users\Jasmina PC\.conda\envs\mlflow\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# c:\Users\Jasmina PC\.conda\envs\mlflow\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# ...

# %% [markdown]
# ## Q6. Promote the best model to the model registry

# %%
# !python "C:/Users/Jasmina PC/Downloads/mlops2/register_model.py" --data_path "C:/Users/Jasmina PC/Downloads/mlops2/output"
# Out:
# Best run ID: 7c9c325bb66e441f9cf45e4869dcbf98, Best test RMSE: 5.567408012462019
# 2024/05/27 23:06:49 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/27 23:07:35 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: Unable to allocate 2.66 GiB for an array with shape (356796948,) and data type float64
# c:\Users\Jasmina PC\.conda\envs\mlflow\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/05/27 23:07:36 WARNING mlflow.sklearn: Failed to log evaluation dataset information to MLflow Tracking. Reason: Unable to allocate 2.95 GiB for an array with shape (395673184,) and data type float64
# ...
